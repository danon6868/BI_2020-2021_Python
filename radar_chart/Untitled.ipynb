# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
from matplotlib.patches import Circle, RegularPolygon

# %%
# Set data
df = pd.DataFrame({
'group': ['A','B','C','D'],
'var1': [38, 1.5, 30, 4],
'var2': [29, 10, 9, 34],
'var3': [8, 39, 23, 24],
'var4': [7, 31, 33, 14],
'var5': [28, 15, 32, 14]
})

# %%
def make_spider( row, title, color):
 
    # number of variable
    categories=list(df)[1:]
    N = len(categories)

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(2,2,row+1, polar=True, )

    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)

    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=8)

    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
    plt.ylim(0,40)

    # Ind1
    values=df.loc[row].drop('group').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    ax.fill(angles, values, color=color, alpha=0.4)

    # Add a title
    plt.title(title, size=11, color=color, y=1.1)

# %%
my_dpi=96
plt.figure(figsize=(1000/my_dpi, 1000/my_dpi), dpi=my_dpi)
my_palette = plt.cm.get_cmap("Set2", len(df.index))
for row in range(0, len(df.index)):
    make_spider(row=row, title='group '+df['group'][row], color=my_palette(row))

# %%
plt.rcParams['figure.dpi']

# %%
plt.rcParams['figure.figsize'] = (10, 8)

# %%
plt.polar()
# Out:
# []

# %%
values = [4, 5, 4, 6, 7, 3]
N = len(values)
values.append(values[0])
angles = [i / float(N) * 2 * pi for i in range(N)]
angles.append(angles[0])
plt.polar(angles, values)

# %%
for i in plt.style.available:
    print(i)
    plt.style.use(i)
    categories = ['Str', 'Dex', 'Con',
              'Int', 'Wis', 'Cha']
    N = len(categories)

    values = [18, 13, 20, 11, 8, 15]
    values.append(values[0])
    angles = [i / N * 2 * pi for i in range(N)]
    angles.append(angles[0])

    plt.polar(angles, values)
    plt.xticks(angles[:-1], categories)

    plt.show()
# Out:
# Solarize_Light2
# _classic_test_patch
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10

# %%
fig = plt.figure(figsize=(10, 8))
ax = plt.subplot(polar='True')

categories = ['Str', 'Dex', 'Con',
              'Int', 'Wis', 'Cha']
N = len(categories)

values = [18, 13, 20, 11, 8, 15]
values.append(values[0])
angles = [i / N * 2 * pi for i in range(N)]
angles.append(angles[0])

plt.polar(angles, values)
plt.xticks(angles[:-1], categories)

ax.set_rlabel_position(45)
plt.yticks([5, 10, 15], color='blue', size=20)
plt.ylim(0, 20)

plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = plt.subplot(polar='True')

categories = ['Str', 'Dex', 'Con',
              'Int', 'Wis', 'Cha']
N = len(categories)

values = [18, 13, 20, 11, 8, 15]
values.append(values[0])
angles = [i / N * 2 * pi for i in range(N)]
angles.append(angles[0])

plt.polar(angles, values)
plt.xticks(angles[:-1], categories)

ax.set_rlabel_position(45)
plt.yticks([5, 10, 15], color='blue', size=20)
plt.ylim(0, 20)



plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = plt.subplot(polar='True')

categories = ['Str', 'Dex', 'Con',
              'Int', 'Wis', 'Cha']
N = len(categories)

values = [18, 13, 20, 11, 8, 15]
values.append(values[0])
angles = [i / N * 2 * pi for i in range(N)]
angles.append(angles[0])



plt.polar(angles, values)
plt.fill(angles, values, alpha=0.2)

plt.xticks(angles[:-1], categories)

ax.set_rlabel_position(45)
plt.yticks([5, 10, 15], color='blue', size=20)
plt.ylim(0, 20)



plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = plt.subplot(polar='True')

categories = ['Str', 'Dex', 'Con',
              'Int', 'Wis', 'Cha', 'ew']
N = len(categories)

values = [18, 13, 20, 11, 8, 15, 9]
values.append(values[0])
angles = [i / N * 2 * pi for i in range(N)]
angles.append(angles[0])



plt.polar(angles, values, marker='.')
plt.fill(angles, values, alpha=0.2)

plt.xticks(angles[:-1], categories)

ax.set_rlabel_position(45)
plt.yticks([5, 10, 15], color='blue', size=20)
plt.ylim(0, 20)



plt.show()

# %% [markdown]
# ## Data preproccesing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
games_data = pd.read_csv('vgsales.csv', index_col=0)

# %%
games_data
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
middle_games_data = games_data.query('(Year >= 2006) & (Year <= 2011)')

# %%
middle_games_data.Year = middle_games_data.Year.astype('int')

# %%
middle_games_data.head()
# Out:
#                        Name Platform  Year     Genre Publisher  NA_Sales  \
# Rank
# 1                Wii Sports      Wii  2006    Sports  Nintendo     41.49
# 3            Mario Kart Wii      Wii  2008    Racing  Nintendo     15.85
# 4         Wii Sports Resort      Wii  2009    Sports  Nintendo     15.75
# 7     New Super Mario Bros.       DS  2006  Platform  Nintendo     11.38
# 8                  Wii Play      Wii  2006      Misc  Nintendo     14.03
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 1        29.02      3.77         8.46         82.74
# 3        12.88      3.79         3.31         35.82
# 4        11.01      3.28         2.96         33.00
# 7         9.23      6.50         2.90         30.01
# 8         9.20      2.93         2.85         29.02

# %%
genres_to_analise = middle_games_data.Genre.value_counts()[:7].index.values

# %%
top_genres_middle_games_data = middle_games_data[middle_games_data.Genre.isin(genres_to_analise)]

# %%
pivot_genres_sales_data = top_genres_middle_games_data.pivot_table(index=['Year', 'Genre'], values='Global_Sales', aggfunc='sum')

# %%
time_sales = {year: pivot_genres_sales_data.loc[year] for year in range(2007, 2011)}

# %%
len(range(2006, 2012))
# Out:
# 6

# %%
pivot_genres_sales_data.head()
# Out:
#                    Global_Sales
# Year Genre
# 2006 Action               66.58
#      Adventure            11.47
#      Misc                 67.35
#      Role-Playing         57.73
#      Shooter              38.37

# %%
fig = plt.figure(figsize=(10, 8))
ax = plt.subplot(polar='True')


values = np.append(time_sales[2006],
                   time_sales[2006].iloc[0])
categories = genres_to_analise

N = len(categories)
angles = [i / N * 2 * pi for i in range(N)]
angles.append(angles[0])


plt.polar(angles, values, marker='.')
ax.legend(('2006',))
plt.fill(angles, values, alpha=0.2)

plt.xticks(angles[:-1], categories)

ax.set_rlabel_position(45)
#plt.yticks([5, 10, 15], color='blue', size=20)
#plt.ylim(0, 20)



plt.show()

# %%
plt.figure(figsize=(10, 8), dpi=96)
my_palette = plt.cm.get_cmap("Set2", len(range(2007, 2011)))
ax = plt.subplot(polar='True')

categories = genres_to_analise
N = len(categories)
angles = [i / N * 2 * pi for i in range(N)]
angles.append(angles[0])

for i, year in enumerate(range(2007, 2011)):
    values = np.append(time_sales[year],
                   time_sales[year].iloc[0])
    plt.polar(angles, values, marker='.', color=my_palette(i))
    plt.fill(angles, values, alpha=0.2, color=my_palette(i))

plt.xticks(angles[:-1], categories)
plt.legend([str(i) for i in range(2007, 2011)])

plt.show()

# %%
time_sales[2006]
# Out:
#               Global_Sales
# Genre
# Action               66.58
# Adventure            11.47
# Misc                 67.35
# Role-Playing         57.73
# Shooter              38.37
# Simulation           21.77
# Sports              136.16

# %%
ax = plt.subplot(2, 2, 1, polar=True)
ax.plot(angles, values)
ax1 = plt.subplot(2, 2, 2, polar=True)
ax1.plot(angles, values)
ax2 = plt.subplot(2, 2, 3, polar=True)
ax2.plot(angles, values)

# %%
games_data.sort_values(['Year']).groupby('Year')['Global_Sales'].sum().plot()
# Out:
# <AxesSubplot:xlabel='Year'>
